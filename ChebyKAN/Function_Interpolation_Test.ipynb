# %% [markdown]
# ## Compare ChebyKAN's ability in function interpolation with MLP

# %%
from google.colab import drive
drive.mount('/content/drive')

import sys
sys.path.append('/content/drive/MyDrive/Colab Notebooks/KAN/ChebyKAN_old/')  # Add the directory to Python's path
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import numpy as np
import matplotlib.pyplot as plt
import time
from ChebyKANLayer import ChebyKANLayer

# %%
# Define target function (piecewise function)
def target_function(x):
    y = np.zeros_like(x)
    mask1 = x < 0.5
    y[mask1] = np.sin(20 * np.pi * x[mask1]) + x[mask1] ** 2
    mask2 = (0.5 <= x) & (x < 1.5)
    y[mask2] = 0.5 * x[mask2] * np.exp(-x[mask2]) + np.abs(np.sin(5 * np.pi * x[mask2]))
    mask3 = x >= 1.5
    y[mask3] = np.log(x[mask3] - 1) / np.log(2) - np.cos(2 * np.pi * x[mask3])

    # add noise
    noise = np.random.normal(0, 0.1, y.shape)
    y_noise = y + noise

    return y, y_noise

# %%
# Define target function (sqrt(x))
def target_function(x):
    y = np.zeros_like(x)
    mask1 = x < 0
    y[mask1] = 0
    mask2 = x >= 0
    y[mask2] = np.sqrt(x[mask2])


    # add noise
    noise = np.random.normal(0, 0.01, y.shape)
    y_noise = y + noise

    return y, y_noise

# %%
# Define target function (x**0.5 * (1-x)**(3/4))
def target_function(x):
    y = np.zeros_like(x)
    mask1 = x < 0
    y[mask1] = 0
    mask2 = (0 <= x) & (x <= 1)
    y[mask2] = x[mask2]**0.5 * (1-x[mask2])**(3/4)
    mask3 = x > 1
    y[mask3] = 0


    # add noise
    noise = np.random.normal(0, 0.01, y.shape)
    y_noise = y + noise

    return y, y_noise

# %%
# Define target function (exp(-x/0.01))
def target_function(x):
    y = np.zeros_like(x)
    mask1 = x >= 0
    y[mask1] = np.exp(-x[mask1]/0.01)




    # add noise
    noise = np.random.normal(0, 0.01, y.shape)
    y_noise = y + noise

    return y, y_noise

# %%
# Define MLP and ChebyKAN
class SimpleMLP(nn.Module):
    def __init__(self):
        super(SimpleMLP, self).__init__()
        self.layers = nn.Sequential(
            nn.Linear(1, 128),
            nn.Tanh(),
            nn.Linear(128, 1),
        )

    def forward(self, x):
        return self.layers(x-1) # centralize the input


class ChebyKAN(nn.Module):
    def __init__(self):
        super(ChebyKAN, self).__init__()
        self.chebykan1 = ChebyKANLayer(1, 44, 44)
        self.chebykan2 = ChebyKANLayer(44, 1, 44)

    def forward(self, x):
        x = self.chebykan1(x)
        x = self.chebykan2(x)
        return x

# %%
# Generate sample data
x_train = torch.linspace(0, 2, steps=500).unsqueeze(1)
y_target, y_train = target_function(x_train)
y_target, y_train = torch.tensor(y_target, dtype = torch.float32), torch.tensor(y_train, dtype = torch.float32)

# Instantiate models
cheby_model = ChebyKAN()
mlp_model = SimpleMLP()

# Define loss function and optimizer
criterion = nn.MSELoss()
optimizer_cheby = torch.optim.Adam(cheby_model.parameters(), lr=0.01)
optimizer_mlp = torch.optim.Adam(mlp_model.parameters(), lr=0.03)

cheby_losses = []

mlp_losses = []


# Train the models
epochs = 2000
for epoch in range(epochs):
    optimizer_cheby.zero_grad()
    outputs_cheby = cheby_model(x_train)
    loss_cheby = criterion(outputs_cheby, y_train)
    loss_cheby_gen = criterion(outputs_cheby, y_target)
    loss_cheby.backward()
    optimizer_cheby.step()

    optimizer_mlp.zero_grad()
    outputs_mlp = mlp_model(x_train)
    loss_mlp = criterion(outputs_mlp, y_train)
    loss_mlp_gen = criterion(outputs_mlp, y_target)
    loss_mlp.backward()
    optimizer_mlp.step()

    if epoch % 100 == 0:
        cheby_losses.append(loss_cheby.item())
        mlp_losses.append(loss_mlp.item())
        print(f'Epoch {epoch + 1}/{epochs}, ChebyKAN training Loss: {loss_cheby.item():.4e}, MLP training Loss: {loss_mlp.item():.4e}')
        print(f'Epoch {epoch + 1}/{epochs}, ChebyKAN generalization Loss: {loss_cheby_gen.item():.4e}, MLP generalization Loss: {loss_mlp_gen.item():.4e}')
        print()
# Test the models
x_test = torch.linspace(0, 2, steps=400).unsqueeze(1)
y_pred_cheby = cheby_model(x_test).detach()
y_pred_mlp = mlp_model(x_test).detach()
# Out:
# Epoch 1/2000, ChebyKAN training Loss: 4.0670e-03, MLP training Loss: 6.8806e-02
# Epoch 1/2000, ChebyKAN generalization Loss: 3.9738e-03, MLP generalization Loss: 6.8707e-02
#
# Epoch 101/2000, ChebyKAN training Loss: 4.1711e-04, MLP training Loss: 3.4584e-03
# Epoch 101/2000, ChebyKAN generalization Loss: 4.4856e-04, MLP generalization Loss: 3.3378e-03
#
# Epoch 201/2000, ChebyKAN training Loss: 2.5505e-04, MLP training Loss: 3.3883e-03
# Epoch 201/2000, ChebyKAN generalization Loss: 2.8837e-04, MLP generalization Loss: 3.2691e-03
#
# Epoch 301/2000, ChebyKAN training Loss: 7.2267e-05, MLP training Loss: 3.3253e-03
# Epoch 301/2000, ChebyKAN generalization Loss: 1.2659e-04, MLP generalization Loss: 3.2077e-03
#
# Epoch 401/2000, ChebyKAN training Loss: 1.5444e-04, MLP training Loss: 3.2667e-03
# Epoch 401/2000, ChebyKAN generalization Loss: 2.0069e-04, MLP generalization Loss: 3.1510e-03
#
# Epoch 501/2000, ChebyKAN training Loss: 1.2522e-02, MLP training Loss: 3.2296e-03
# Epoch 501/2000, ChebyKAN generalization Loss: 1.2725e-02, MLP generalization Loss: 3.1157e-03
#
# Epoch 601/2000, ChebyKAN training Loss: 3.1556e-05, MLP training Loss: 3.2098e-03
# Epoch 601/2000, ChebyKAN generalization Loss: 8.3763e-05, MLP generalization Loss: 3.0969e-03
#
# Epoch 701/2000, ChebyKAN training Loss: 7.8599e-05, MLP training Loss: 3.1921e-03
# Epoch 701/2000, ChebyKAN generalization Loss: 1.4068e-04, MLP generalization Loss: 3.0794e-03
#
# Epoch 801/2000, ChebyKAN training Loss: 6.8453e-03, MLP training Loss: 3.1710e-03
# Epoch 801/2000, ChebyKAN generalization Loss: 6.8118e-03, MLP generalization Loss: 3.0582e-03
#
# Epoch 901/2000, ChebyKAN training Loss: 2.3317e-05, MLP training Loss: 1.0348e-02
# Epoch 901/2000, ChebyKAN generalization Loss: 8.1671e-05, MLP generalization Loss: 1.0254e-02
#
# Epoch 1001/2000, ChebyKAN training Loss: 5.3589e-05, MLP training Loss: 3.1495e-03
# Epoch 1001/2000, ChebyKAN generalization Loss: 9.6820e-05, MLP generalization Loss: 3.0360e-03
#
# Epoch 1101/2000, ChebyKAN training Loss: 3.8145e-04, MLP training Loss: 3.1236e-03
# Epoch 1101/2000, ChebyKAN generalization Loss: 4.5510e-04, MLP generalization Loss: 3.0100e-03
#
# Epoch 1201/2000, ChebyKAN training Loss: 2.1217e-05, MLP training Loss: 3.0943e-03
# Epoch 1201/2000, ChebyKAN generalization Loss: 8.0104e-05, MLP generalization Loss: 2.9802e-03
#
# Epoch 1301/2000, ChebyKAN training Loss: 2.0088e-05, MLP training Loss: 3.0615e-03
# Epoch 1301/2000, ChebyKAN generalization Loss: 8.0362e-05, MLP generalization Loss: 2.9468e-03
#
# Epoch 1401/2000, ChebyKAN training Loss: 1.1775e-03, MLP training Loss: 3.0270e-03
# Epoch 1401/2000, ChebyKAN generalization Loss: 1.2502e-03, MLP generalization Loss: 2.9116e-03
#
# Epoch 1501/2000, ChebyKAN training Loss: 2.3546e-05, MLP training Loss: 2.9931e-03
# Epoch 1501/2000, ChebyKAN generalization Loss: 7.9784e-05, MLP generalization Loss: 2.8771e-03
#
# Epoch 1601/2000, ChebyKAN training Loss: 2.1540e-05, MLP training Loss: 2.9601e-03
# Epoch 1601/2000, ChebyKAN generalization Loss: 7.9962e-05, MLP generalization Loss: 2.8436e-03
#
# Epoch 1701/2000, ChebyKAN training Loss: 2.0585e-05, MLP training Loss: 2.9259e-03
# Epoch 1701/2000, ChebyKAN generalization Loss: 8.0561e-05, MLP generalization Loss: 2.8094e-03
#
# Epoch 1801/2000, ChebyKAN training Loss: 2.5170e-05, MLP training Loss: 2.8879e-03
# Epoch 1801/2000, ChebyKAN generalization Loss: 8.4716e-05, MLP generalization Loss: 2.7718e-03
#
# Epoch 1901/2000, ChebyKAN training Loss: 1.9672e-05, MLP training Loss: 2.9523e-03
# Epoch 1901/2000, ChebyKAN generalization Loss: 8.1800e-05, MLP generalization Loss: 2.8385e-03

# %%
# Plot the results
plt.figure(figsize=(10, 5))
plt.plot(x_train.numpy(), y_target.numpy(), 'ro', label='Original Data')
plt.plot(x_test.numpy(), y_pred_cheby.numpy(), 'b-', label='ChebyKAN')
plt.plot(x_test.numpy(), y_pred_mlp.numpy(), 'g--', label='MLP')
plt.title('Comparison of ChebyKAN and MLP Interpolations f(x)')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.show()

# %%
# Plot the convergence speed
# Plotting
plt.figure(figsize=(10, 5))
plt.plot(range(0, epochs, 100), cheby_losses, 'b-', label='ChebyKAN')
plt.plot(range(0, epochs, 100), mlp_losses, 'g--', label='MLP')
plt.title('Convergence Speed Comparison Between ChebyKAN and MLP')
plt.xlim(0, 2000)
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
